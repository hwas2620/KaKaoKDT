# %% [markdown]
# | SSH Deamon | bash | disk | mem | cpu | process |
# |---|---|---|---|---|---|
# | | tty terminal | | | | |
# | kernal |

# %% [markdown]
# pwd
# cd
# ls
# ls -l
# .
# ..
# mkdir
# touch
# cat
# cp
# mv
# 물리적 저장 방식(하드 드라이브) <-> 논리적 저장 방식( - )
# ln
# 하드 링크, 소프트 링크
# find
# 텍스트 에디터 - vi(vim)
# 환경변수
