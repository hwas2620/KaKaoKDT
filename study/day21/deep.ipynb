# %% [markdown]
# ### 딥러닝
# * 전통적 접근법: 개발자가 직접 특징을 설계
# * 딥러닝 접근법: 모델이 스스로 중요한 패턴을 찾아냄
#
# 신경망?
# 순전파(입력 -> 신경망 -> 예측값)를 통해 예측값을 계산해내고
# 손실 계산(실제값 - 예측값) 후 역전파를 통해 가중치를 조정

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

plt.rc('font', family='AppleGothic')

# 입력값
study_hour = 0.5
attentdance_rate = 0.8
fast_rate = 0.2

w_study = 0.4
w_attendance = 0.7
w_past = 0.3
